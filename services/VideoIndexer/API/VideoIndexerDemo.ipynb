# %%
from dotenv import dotenv_values
from pprint import pprint
import os

from VideoIndexerClient.Consts import Consts
from VideoIndexerClient.VideoIndexerClient import VideoIndexerClient

# %%
config = dotenv_values(".env")

AccountName = config.get('AccountName') # Should be the name of the video indexer account
ResourceGroup = config.get('ResourceGroup')
SubscriptionId = config.get('SubscriptionId')

ApiVersion = '2024-01-01'
ApiEndpoint = 'https://api.videoindexer.ai'
AzureResourceManager = 'https://management.azure.com'

# create and validate consts
consts = Consts(ApiVersion, ApiEndpoint, AzureResourceManager, AccountName, ResourceGroup, SubscriptionId)

# %%
# Authenticate

# create Video Indexer Client
client = VideoIndexerClient()

# Get access tokens (arm and Video Indexer account)
client.authenticate_async(consts)

# %% [markdown]
# ### Get Basic Account Details
# <hr>

# %%
client.get_account_async()
# Out:
# [Account Details] Id:84bdc98e-e016-4228-b796-c43bb634905a, Location: eastus

# %% [markdown]
# ### Index a Video from URL
# <hr>

# %%
VideoURL = 'https://www.youtube.com/watch?v=v9Zun9iD0IQ'
ExcludedAI = [] # Faces, Labels, Emotions, ObservedPeople

video_id = client.upload_url_async('Hot Dog', VideoURL, ExcludedAI, False)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 4>()
#       1 VideoURL = 'https://www.youtube.com/watch?v=v9Zun9iD0IQ'
#       2 ExcludedAI = [] # Faces, Labels, Emotions, ObservedPeople
# ----> 4 video_id = client.upload_url_async('Hot Dog', VideoURL, ExcludedAI, False)
#
# File c:\Users\mezzo\OneDrive - SkillStorm\SkillStorm\Tech\AI\Accelerator - AI-102\StormSurge-AzureAISolutions\code\VideoIndexer\API\VideoIndexerClient\VideoIndexerClient.py:90, in VideoIndexerClient.upload_url_async(self, video_name, video_url, excluded_ai, wait_for_index, video_description, privacy)
#      86     params['excludedAI'] = ','.join(excluded_ai)
#      88 response = requests.post(url, params=params)
# ---> 90 response.raise_for_status()
#      92 video_id = response.json().get('id')
#      93 print(f'Video ID {video_id} was uploaded successfully')
#
# File c:\Users\mezzo\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\models.py:960, in Response.raise_for_status(self)
#     957     http_error_msg = u'%s Server Error: %s for url: %s' % (self.status_code, reason, self.url)
#     959 if http_error_msg:
# --> 960     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 400 Client Error: Bad Request for url: https://api.videoindexer.ai/eastus/Accounts/84bdc98e-e016-4228-b796-c43bb634905a/Videos?accessToken=eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9.....e9V4f-ltyht9FtyeJ3vO-CmtfYre3AzyYmvKU0XOrShweccMfj12z1QtCWhz5bdg0-2nK87eweEPd3AVh3B-iCqcqaWjLONyOUUzN3_8bMsGlg3grmVTkGJ7wysBgDo3c56RQvRxoGiMmwwOcHBMy1eNc_tZuzKyNWna9a_5X73kzcnrTYJygrOw6q7WEBfCOSZgQygXjLznxvSSzNDY08S0vPAdrNLmO9ZK6c5zdr_uxr6Mv4gzPlIlwtIVyuWTaj-U2_ZLcuFMeWvAV4YU7kb3K5fSQ1yEg7vTGnNZTnrwLRDLbVtIbJVEUnvSoceZjG3kBGY2YvofRHjXw4PVJA&name=Hot+Dog&description=&privacy=private&videoUrl=https%3A%2F%2Fwww.youtube.com%2Fwatch%3Fv%3Dv9Zun9iD0IQ

# %%
LocalVideoPath = 'media/6127664-uhd_2160_4096_25fps.mp4'

file_video_id = client.file_upload_async(LocalVideoPath, video_name='Sales', excluded_ai=ExcludedAI)
# Out:
# Uploading a local file using multipart/form-data post request..

# %% [markdown]
# ### Poll for Video Indexing Completion
# <hr>

# %%
client.wait_for_index_async(file_video_id)
# Out:
# Checking if video wufte6jyyg has finished indexing...
# The video index state is Processing
# The video index state is Processing
# The video index state is Processing
# The video index state is Processing
# The video index state is Processing
# The video index state is Processing
# The video index state is Processing
# The video index state is Processing
# The video index state is Processing
# The video index state is Processing
# The video index state is Processing
# The video index state is Processing
# The video index state is Processing
# The video index state is Processing
# The video index has completed. Here is the full JSON of the index for video ID wufte6jyyg:
# {'partition': None, 'description': None, 'privacyMode': 'Private', 'state': 'Processed', 'accountId': '84bdc98e-e016-4228-b796-c43bb634905a', 'id': 'wufte6jyyg', 'name': 'Sales', 'userName': 'Lee Speers', 'created': '2024-10-04T21:48:41.4366667+00:00', 'isOwned': True, 'isEditable': True, 'isBase': True, 'durationInSeconds': 42, 'duration': '0:00:42.4799999', 'summarizedInsights': {'name': 'Sales', 'id': 'wufte6jyyg', 'privacyMode': 'Private', 'duration': {'time': '0:00:42.4799999', 'seconds': 42.5}, 'thumbnailVideoId': 'wufte6jyyg', 'thumbnailId': '5273bf0c-2c39-4ef0-b9fb-5977f3ca4bac', 'faces': [{'videoId': 'wufte6jyyg', 'confidence': 0, 'description': None, 'title': None, 'thumbnailId': 'ffd49a5c-18a1-420c-bbfd-5a5886010688', 'seenDuration': 42.5, 'seenDurationRatio': 1, 'id': 1009, 'name': 'Unknown #1', 'appearances': [{'startTime': '0:00:00', 'endTime': '0:00:42.4799999', 'startSeconds': 0, 'endSeconds': 42.5}]}, {'videoId': 'wufte6jyyg', 'confidence': 0, 'description': None, 'title': None, 'thumbnailId': 'c97523ac-9434-48d8-b288-7c3bfd8f63ff', 'seenDuration': 11, 'seenDurationRatio': 0.2589, 'id': 1011, 'name': 'Unknown #2', 'appearances': [{'startTime': '0:00:05.76', 'endTime': '0:00:08.2', 'startSeconds': 5.8, 'endSeconds': 8.2}, {'startTime': '0:00:20.16', 'endTime': '0:00:28.84', 'startSeconds': 20.2, 'endSeconds': 28.8}]}], 'keywords': [], 'sentiments': [], 'emotions': [], 'audioEffects': [], 'labels': [{'id': 1, 'name': 'clothing', 'appearances': [{'confidence': 0.9966, 'startTime': '0:00:00', 'endTime': '0:00:42.04', 'startSeconds': 0, 'endSeconds': 42}]}, {'id': 2, 'name': 'person', 'appearances': [{'confidence': 0.9939, 'startTime': '0:00:00', 'endTime': '0:00:42.04', 'startSeconds': 0, 'endSeconds': 42}]}, {'id': 3, 'name': 'human face', 'appearances': [{'confidence': 0.9881, 'startTime': '0:00:00', 'endTime': '0:00:42.04', 'startSeconds': 0, 'endSeconds': 42}]}, {'id': 4, 'name': 'indoor', 'appearances': [{'confidence': 0.9539, 'startTime': '0:00:00', 'endTime': '0:00:05.04', 'startSeconds': 0, 'endSeconds': 5}, {'confidence': 0.9729, 'startTime': '0:00:09', 'endTime': '0:00:42.04', 'startSeconds': 9, 'endSeconds': 42}]}, {'id': 6, 'name': 'wall', 'appearances': [{'confidence': 0.9651, 'startTime': '0:00:09', 'endTime': '0:00:09.04', 'startSeconds': 9, 'endSeconds': 9}, {'confidence': 0.9579, 'startTime': '0:00:19', 'endTime': '0:00:40.04', 'startSeconds': 19, 'endSeconds': 40}]}, {'id': 8, 'name': 'man', 'appearances': [{'confidence': 0.9583, 'startTime': '0:00:11', 'endTime': '0:00:11.04', 'startSeconds': 11, 'endSeconds': 11}, {'confidence': 0.9566, 'startTime': '0:00:20', 'endTime': '0:00:20.04', 'startSeconds': 20, 'endSeconds': 20}, {'confidence': 0.9538, 'startTime': '0:00:24', 'endTime': '0:00:34.04', 'startSeconds': 24, 'endSeconds': 34}]}, {'id': 7, 'name': 'drink', 'appearances': [{'confidence': 0.9632, 'startTime': '0:00:11', 'endTime': '0:00:18.04', 'startSeconds': 11, 'endSeconds': 18}, {'confidence': 0.9641, 'startTime': '0:00:22', 'endTime': '0:00:24.04', 'startSeconds': 22, 'endSeconds': 24}]}, {'id': 5, 'name': 'coat', 'appearances': [{'confidence': 0.9524, 'startTime': '0:00:02', 'endTime': '0:00:03.04', 'startSeconds': 2, 'endSeconds': 3}]}, {'id': 9, 'name': 'wine glass', 'appearances': [{'confidence': 0.9633, 'startTime': '0:00:17', 'endTime': '0:00:18.04', 'startSeconds': 17, 'endSeconds': 18}, {'confidence': 0.9534, 'startTime': '0:00:23', 'endTime': '0:00:23.04', 'startSeconds': 23, 'endSeconds': 23}]}, {'id': 10, 'name': 'suit', 'appearances': [{'confidence': 0.9591, 'startTime': '0:00:32', 'endTime': '0:00:32.04', 'startSeconds': 32, 'endSeconds': 32}]}], 'framePatterns': [], 'brands': [], 'namedLocations': [], 'namedPeople': [], 'statistics': {'correspondenceCount': 0, 'speakerTalkToListenRatio': {}, 'speakerLongestMonolog': {}, 'speakerNumberOfFragments': {}, 'speakerWordCount': {}}, 'topics': []}, 'videos': [{'accountId': '84bdc98e-e016-4228-b796-c43bb634905a', 'id': 'wufte6jyyg', ...

# %% [markdown]
# ### Get Video Insights
# <hr>

# %%
insights = client.get_video_async(file_video_id)
pprint(insights)
# Out:
# Searching videos in account 84bdc98e-e016-4228-b796-c43bb634905a for video ID wufte6jyyg.
# Here are the search results:
# {'partition': None, 'description': None, 'privacyMode': 'Private', 'state': 'Processed', 'accountId': '84bdc98e-e016-4228-b796-c43bb634905a', 'id': 'wufte6jyyg', 'name': 'Sales', 'userName': 'Lee Speers', 'created': '2024-10-04T21:48:41.4366667+00:00', 'isOwned': True, 'isEditable': True, 'isBase': True, 'durationInSeconds': 42, 'duration': '0:00:42.4799999', 'summarizedInsights': {'name': 'Sales', 'id': 'wufte6jyyg', 'privacyMode': 'Private', 'duration': {'time': '0:00:42.4799999', 'seconds': 42.5}, 'thumbnailVideoId': 'wufte6jyyg', 'thumbnailId': '5273bf0c-2c39-4ef0-b9fb-5977f3ca4bac', 'faces': [{'videoId': 'wufte6jyyg', 'confidence': 0, 'description': None, 'title': None, 'thumbnailId': 'ffd49a5c-18a1-420c-bbfd-5a5886010688', 'seenDuration': 42.5, 'seenDurationRatio': 1, 'id': 1009, 'name': 'Unknown #1', 'appearances': [{'startTime': '0:00:00', 'endTime': '0:00:42.4799999', 'startSeconds': 0, 'endSeconds': 42.5}]}, {'videoId': 'wufte6jyyg', 'confidence': 0, 'description': None, 'title': None, 'thumbnailId': 'c97523ac-9434-48d8-b288-7c3bfd8f63ff', 'seenDuration': 11, 'seenDurationRatio': 0.2589, 'id': 1011, 'name': 'Unknown #2', 'appearances': [{'startTime': '0:00:05.76', 'endTime': '0:00:08.2', 'startSeconds': 5.8, 'endSeconds': 8.2}, {'startTime': '0:00:20.16', 'endTime': '0:00:28.84', 'startSeconds': 20.2, 'endSeconds': 28.8}]}], 'keywords': [], 'sentiments': [], 'emotions': [], 'audioEffects': [], 'labels': [{'id': 1, 'name': 'clothing', 'appearances': [{'confidence': 0.9966, 'startTime': '0:00:00', 'endTime': '0:00:42.04', 'startSeconds': 0, 'endSeconds': 42}]}, {'id': 2, 'name': 'person', 'appearances': [{'confidence': 0.9939, 'startTime': '0:00:00', 'endTime': '0:00:42.04', 'startSeconds': 0, 'endSeconds': 42}]}, {'id': 3, 'name': 'human face', 'appearances': [{'confidence': 0.9881, 'startTime': '0:00:00', 'endTime': '0:00:42.04', 'startSeconds': 0, 'endSeconds': 42}]}, {'id': 4, 'name': 'indoor', 'appearances': [{'confidence': 0.9539, 'startTime': '0:00:00', 'endTime': '0:00:05.04', 'startSeconds': 0, 'endSeconds': 5}, {'confidence': 0.9729, 'startTime': '0:00:09', 'endTime': '0:00:42.04', 'startSeconds': 9, 'endSeconds': 42}]}, {'id': 6, 'name': 'wall', 'appearances': [{'confidence': 0.9651, 'startTime': '0:00:09', 'endTime': '0:00:09.04', 'startSeconds': 9, 'endSeconds': 9}, {'confidence': 0.9579, 'startTime': '0:00:19', 'endTime': '0:00:40.04', 'startSeconds': 19, 'endSeconds': 40}]}, {'id': 8, 'name': 'man', 'appearances': [{'confidence': 0.9583, 'startTime': '0:00:11', 'endTime': '0:00:11.04', 'startSeconds': 11, 'endSeconds': 11}, {'confidence': 0.9566, 'startTime': '0:00:20', 'endTime': '0:00:20.04', 'startSeconds': 20, 'endSeconds': 20}, {'confidence': 0.9538, 'startTime': '0:00:24', 'endTime': '0:00:34.04', 'startSeconds': 24, 'endSeconds': 34}]}, {'id': 7, 'name': 'drink', 'appearances': [{'confidence': 0.9632, 'startTime': '0:00:11', 'endTime': '0:00:18.04', 'startSeconds': 11, 'endSeconds': 18}, {'confidence': 0.9641, 'startTime': '0:00:22', 'endTime': '0:00:24.04', 'startSeconds': 22, 'endSeconds': 24}]}, {'id': 5, 'name': 'coat', 'appearances': [{'confidence': 0.9524, 'startTime': '0:00:02', 'endTime': '0:00:03.04', 'startSeconds': 2, 'endSeconds': 3}]}, {'id': 9, 'name': 'wine glass', 'appearances': [{'confidence': 0.9633, 'startTime': '0:00:17', 'endTime': '0:00:18.04', 'startSeconds': 17, 'endSeconds': 18}, {'confidence': 0.9534, 'startTime': '0:00:23', 'endTime': '0:00:23.04', 'startSeconds': 23, 'endSeconds': 23}]}, {'id': 10, 'name': 'suit', 'appearances': [{'confidence': 0.9591, 'startTime': '0:00:32', 'endTime': '0:00:32.04', 'startSeconds': 32, 'endSeconds': 32}]}], 'framePatterns': [], 'brands': [], 'namedLocations': [], 'namedPeople': [], 'statistics': {'correspondenceCount': 0, 'speakerTalkToListenRatio': {}, 'speakerLongestMonolog': {}, 'speakerNumberOfFragments': {}, 'speakerWordCount': {}}, 'topics': []}, 'videos': [{'accountId': '84bdc98e-e016-4228-b796-c43bb634905a', 'id': 'wufte6jyyg', ...
# {'accountId': '84bdc98e-e016-4228-b796-c43bb634905a',
#  'created': '2024-10-04T21:48:41.4366667+00:00',
#  'description': None,
#  'duration': '0:00:42.4799999',
#  'durationInSeconds': 42,
#  'id': 'wufte6jyyg',
#  'isBase': True,
#  'isEditable': True,
#  'isOwned': True,
#  'name': 'Sales',
#  'partition': None,
#  'privacyMode': 'Private',
#  'state': 'Processed',
#  'summarizedInsights': {'audioEffects': [],
#                         'brands': [],
#                         'duration': {'seconds': 42.5,
#                                      'time': '0:00:42.4799999'},
#                         'emotions': [],
#                         'faces': [{'appearances': [{'endSeconds': 42.5,
#                                                     'endTime': '0:00:42.4799999',
#                                                     'startSeconds': 0,
#                                                     'startTime': '0:00:00'}],
#                                    'confidence': 0,
#                                    'description': None,
#                                    'id': 1009,
#                                    'name': 'Unknown #1',
#                                    'seenDuration': 42.5,
#                                    'seenDurationRatio': 1,
#                                    'thumbnailId': 'ffd49a5c-18a1-420c-bbfd-5a5886010688',
#                                    'title': None,
#                                    'videoId': 'wufte6jyyg'},
#                                   {'appearances': [{'endSeconds': 8.2,
#                                                     'endTime': '0:00:08.2',
#                                                     'startSeconds': 5.8,
#                                                     'startTime': '0:00:05.76'},
#                                                    {'endSeconds': 28.8,
#                                                     'endTime': '0:00:28.84',
#                                                     'startSeconds': 20.2,
#                                                     'startTime': '0:00:20.16'}],
#                                    'confidence': 0,
#                                    'description': None,
#                                    'id': 1011,
#                                    'name': 'Unknown #2',
#                                    'seenDuration': 11,
#                                    'seenDurationRatio': 0.2589,
#                                    'thumbnailId': 'c97523ac-9434-48d8-b288-7c3bfd8f63ff',
#                                    'title': None,
#                                    'videoId': 'wufte6jyyg'}],
#                         'framePatterns': [],
#                         'id': 'wufte6jyyg',
#                         'keywords': [],
#                         'labels': [{'appearances': [{'confidence': 0.9966,
#                                                      'endSeconds': 42,
#                                                      'endTime': '0:00:42.04',
#                                                      'startSeconds': 0,
#                                                      'startTime': '0:00:00'}],
#                                     'id': 1,
#                                     'name': 'clothing'},
#                                    {'appearances': [{'confidence': 0.9939,
#                                                      'endSeconds': 42,
#                                                      'endTime': '0:00:42.04',
#                                                      'startSeconds': 0,
#                                                      'startTime': '0:00:00'}],
#                                     'id': 2,
#                                     'name': 'person'},
#                                    {'appearances': [{'confidence': 0.9881,
#                                                      'endSeconds': 42,
#                                                      'endTime': '0:00:42.04',
#                                                      'startSeconds': 0,
#                                                      'startTime': '0:00:00'}],
#                                     'id': 3,
#                                     'name': 'human face'},
#                                    {'appearances': [{'confidence': 0.9539,
#                                                      'endSeconds': 5,
#                                                      'endTime': '0:00:05.04',
#                                                      'startSeconds': 0,
#                                                      'startTime': '0:00:00'},
#                                                     {'confidence': 0.9729,
#                                                      'endSeconds': 42,
#                                                      'endTime': '0:00:42.04',
#                                                      'startSeconds': 9,
#                                                      'startTime': '0:00:09'}],
#                                     'id': 4,
#                                     'name': 'indoor'},
#                                    {'appearances': [{'confidence': 0.9651,
#                                                      'endSeconds': 9,
#                                                      'endTime': '0:00:09.04',
#                                                      'startSeconds': 9,
#                                                      'startTime': '0:00:09'},
#                                                     {'confidence': 0.9579,
#                                                      'endSeconds': 40,
#                                                      'endTime': '0:00:40.04',
#                                                      'startSeconds': 19,
#                                                      'startTime': '0:00:19'}],
#                                     'id': 6,
#                                     'name': 'wall'},
#                                    {'appearances': [{'confidence': 0.9583,
#                                                      'endSeconds': 11,
#                                                      'endTime': '0:00:11.04',
#                                                      'startSeconds': 11,
#                                                      'startTime': '0:00:11'},
#                                                     {'confidence': 0.9566,
#                                                      'endSeconds': 20,
#                                                      'endTime': '0:00:20.04',
#                                                      'startSeconds': 20,
#                                                      'startTime': '0:00:20'},
#                                                     {'confidence': 0.9538,
#                                                      'endSeconds': 34,
#                                                      'endTime': '0:00:34.04',
#                                                      'startSeconds': 24,
#                                                      'startTime': '0:00:24'}],
#                                     'id': 8,
#                                     'name': 'man'},
#                                    {'appearances': [{'confidence': 0.9632,
#                                                      'endSeconds': 18,
#                                                      'endTime': '0:00:18.04',
#                                                      'startSeconds': 11,
#                                                      'startTime': '0:00:11'},
#                                                     {'confidence': 0.9641,
#                                                      'endSeconds': 24,
#                                                      'endTime': '0:00:24.04',
#                                                      'startSeconds': 22,
#                                                      'startTime': '0:00:22'}],
#                                     'id': 7,
#                                     'name': 'drink'},
#                                    {'appearances': [{'confidence': 0.9524,
#                                                      'endSeconds': 3,
#                                                      'endTime': '0:00:03.04',
#                                                      'startSeconds': 2,
#                                                      'startTime': '0:00:02'}],
#                                     'id': 5,
#                                     'name': 'coat'},
#                                    {'appearances': [{'confidence': 0.9633,
#                                                      'endSeconds': 18,
#                                                      'endTime': '0:00:18.04',
#                                                      'startSeconds': 17,
#                                                      'startTime': '0:00:17'},
#                                                     {'confidence': 0.9534,
#                                                      'endSeconds': 23,
#                                                      'endTime': '0:00:23.04',
#                                                      'startSeconds': 23,
#                                                      'startTime': '0:00:23'}],
#                                     'id': 9,
#                                     'name': 'wine glass'},
#                                    {'appearances': [{'confidence': 0.9591,
#                                                      'endSeconds': 32,
#                                                      'endTime': '0:00:32.04',
#                                                      'startSeconds': 32,
#                                                      'startTime': '0:00:32'}],
#                                     'id': 10,
#                                     'name': 'suit'}],
#                         'name': 'Sales',
#                         'namedLocations': [],
#                         'namedPeople': [],
#                         'privacyMode': 'Private',
#                         'sentiments': [],
#                         'statistics': {'correspondenceCount': 0,
#                                        'speakerLongestMonolog': {},
#                                        'speakerNumberOfFragments': {},
#                                        'speakerTalkToListenRatio': {},
#                                        'speakerWordCount': {}},
#                         'thumbnailId': '5273bf0c-2c39-4ef0-b9fb-5977f3ca4bac',
#                         'thumbnailVideoId': 'wufte6jyyg',
#                         'topics': []},
#  'userName': 'Lee Speers',
#  'videos': [{'accountId': '84bdc98e-e016-4228-b796-c43bb634905a',
#              'detectSourceLanguage': False,
#              'excludedAIs': [],
#              'externalId': None,
#              'externalUrl': None,
#              'failureMessage': '',
#              'height': 4096,
#              'id': 'wufte6jyyg',
#              'indexingPreset': 'Default',
#              'insights': {'detectedObjects': [{'displayName': 'dining table',
#                                                'id': 1,
#                                                'instances': [{'adjustedEnd': '0:00:00.64',
#                                                               'adjustedStart': '0:00:00',
#                                                               'confidence': 0.218,
#                                                               'end': '0:00:00.64',
#                                                               'start': '0:00:00'},
#                                                              {'adjustedEnd': '0:00:02.04',
#                                                               'adjustedStart': '0:00:01.2',
#                                                               'confidence': 0.238,
#                                                               'end': '0:00:02.04',
#                                                               'start': '0:00:01.2'},
#                                                              {'adjustedEnd': '0:00:03.64',
#                                                               'adjustedStart': '0:00:02.6',
#                                                               'confidence': 0.244,
#                                                               'end': '0:00:03.64',
#                                                               'start': '0:00:02.6'},
#                                                              {'adjustedEnd': '0:00:18.44',
#                                                               'adjustedStart': '0:00:07',
#                                                               'confidence': 0.393,
#                                                               'end': '0:00:18.44',
#                                                               'start': '0:00:07'},
#                                                              {'adjustedEnd': '0:00:42.4799999',
#                                                               'adjustedStart': '0:00:19.4',
#                                                               'confidence': 0.517,
#                                                               'end': '0:00:42.4799999',
#                                                               'start': '0:00:19.4'}],
#                                                'thumbnailId': 'd41b2e00-7018-4fc7-bac9-bce996f48509',
#                                                'type': 'DiningTable',
#                                                'wikiDataId': 'Q10552108'},
#                                               {'displayName': 'necktie',
#                                                'id': 2,
#                                                'instances': [{'adjustedEnd': '0:00:01.24',
#                                                               'adjustedStart': '0:00:00.4',
#                                                               'confidence': 0.688,
#                                                               'end': '0:00:01.24',
#                                                               'start': '0:00:00.4'},
#                                                              {'adjustedEnd': '0:00:02.64',
#                                                               'adjustedStart': '0:00:01.8',
#                                                               'confidence': 0.602,
#                                                               'end': '0:00:02.64',
#                                                               'start': '0:00:01.8'},
#                                                              {'adjustedEnd': '0:00:16.84',
#                                                               'adjustedStart': '0:00:15.8',
#                                                               'confidence': 0.612,
#                                                               'end': '0:00:16.84',
#                                                               'start': '0:00:15.8'},
#                                                              {'adjustedEnd': '0:00:18.04',
#                                                               'adjustedStart': '0:00:18',
#                                                               'confidence': 0.537,
#                                                               'end': '0:00:18.04',
#                                                               'start': '0:00:18'},
#                                                              {'adjustedEnd': '0:00:19.84',
#                                                               'adjustedStart': '0:00:19.8',
#                                                               'confidence': 0.517,
#                                                               'end': '0:00:19.84',
#                                                               'start': '0:00:19.8'},
#                                                              {'adjustedEnd': '0:00:25.84',
#                                                               'adjustedStart': '0:00:25.8',
#                                                               'confidence': 0.517,
#                                                               'end': '0:00:25.84',
#                                                               'start': '0:00:25.8'},
#                                                              {'adjustedEnd': '0:00:35.84',
#                                                               'adjustedStart': '0:00:29.6',
#                                                               'confidence': 0.571,
#                                                               'end': '0:00:35.84',
#                                                               'start': '0:00:29.6'},
#                                                              {'adjustedEnd': '0:00:37.64',
#                                                               'adjustedStart': '0:00:36.4',
#                                                               'confidence': 0.581,
#                                                               'end': '0:00:37.64',
#                                                               'start': '0:00:36.4'}],
#                                                'thumbnailId': 'cd15f967-eba7-4584-b485-48e6ff3d8bd8',
#                                                'type': 'Necktie',
#                                                'wikiDataId': 'Q44416'},
#                                               {'displayName': 'necktie',
#                                                'id': 3,
#                                                'instances': [{'adjustedEnd': '0:00:07.84',
#                                                               'adjustedStart': '0:00:07.4',
#                                                               'confidence': 0.56,
#                                                               'end': '0:00:07.84',
#                                                               'start': '0:00:07.4'}],
#                                                'thumbnailId': '98e2bf4d-8e25-494c-b162-44f28315134e',
#                                                'type': 'Necktie',
#                                                'wikiDataId': 'Q44416'},
#                                               {'displayName': 'wine glass',
#                                                'id': 4,
#                                                'instances': [{'adjustedEnd': '0:00:18.84',
#                                                               'adjustedStart': '0:00:09.2',
#                                                               'confidence': 0.485,
#                                                               'end': '0:00:18.84',
#                                                               'start': '0:00:09.2'},
#                                                              {'adjustedEnd': '0:00:27.44',
#                                                               'adjustedStart': '0:00:20.2',
#                                                               'confidence': 0.813,
#                                                               'end': '0:00:27.44',
#                                                               'start': '0:00:20.2'},
#                                                              {'adjustedEnd': '0:00:32.44',
#                                                               'adjustedStart': '0:00:31',
#                                                               'confidence': 0.335,
#                                                               'end': '0:00:32.44',
#                                                               'start': '0:00:31'},
#                                                              {'adjustedEnd': '0:00:40.04',
#                                                               'adjustedStart': '0:00:39.6',
#                                                               'confidence': 0.704,
#                                                               'end': '0:00:40.04',
#                                                               'start': '0:00:39.6'}],
#                                                'thumbnailId': 'd5296157-21e7-4d9e-9886-289e729e4844',
#                                                'type': 'WineGlass',
#                                                'wikiDataId': 'Q1531435'},
#                                               {'displayName': 'necktie',
#                                                'id': 5,
#                                                'instances': [{'adjustedEnd': '0:00:11.64',
#                                                               'adjustedStart': '0:00:11.2',
#                                                               'confidence': 0.524,
#                                                               'end': '0:00:11.64',
#                                                               'start': '0:00:11.2'},
#                                                              {'adjustedEnd': '0:00:14.04',
#                                                               'adjustedStart': '0:00:13.6',
#                                                               'confidence': 0.52,
#                                                               'end': '0:00:14.04',
#                                                               'start': '0:00:13.6'}],
#                                                'thumbnailId': '05548d57-0763-40ff-9315-cbc37b204bb3',
#                                                'type': 'Necktie',
#                                                'wikiDataId': 'Q44416'}],
#                           'duration': '0:00:42.4799999',
#                           'faces': [{'confidence': 0,
#                                      'description': None,
#                                      'highQuality': True,
#                                      'id': 1009,
#                                      'imageUrl': None,
#                                      'instances': [{'adjustedEnd': '0:00:04.08',
#                                                     'adjustedStart': '0:00:00',
#                                                     'end': '0:00:04.08',
#                                                     'start': '0:00:00',
#                                                     'thumbnailsIds': ['1d06b270-1b17-47fe-8f1a-c2708f6cdd61']},
#                                                    {'adjustedEnd': '0:00:42.4799999',
#                                                     'adjustedStart': '0:00:04.84',
#                                                     'end': '0:00:42.4799999',
#                                                     'start': '0:00:04.84',
#                                                     'thumbnailsIds': ['40898828-b03b-45d1-95fa-d57ca90c0cc7',
#                                                                       '45799e86-4d84-46f1-8ea4-7698c7f39db2',
#                                                                       'e19ddd83-7cde-46a5-b10d-cb933851894b',
#                                                                       '46d47124-e670-4c08-be4a-6922118e3872',
#                                                                       '1d40691b-bc50-419a-b4d7-42ca864d081a',
#                                                                       'aa41548a-f844-4bc1-addb-655baa2c8c87',
#                                                                       'b1b24daf-3f6c-40ff-a285-03cdc9fc86e3',
#                                                                       '4daff412-d821-4e48-874b-de4862d38001',
#                                                                       '18a5ab13-378a-498e-b8cf-884e9d0c9bc4']}],
#                                      'name': 'Unknown #1',
#                                      'thumbnailId': 'ffd49a5c-18a1-420c-bbfd-5a5886010688',
#                                      'thumbnails': [{'fileName': 'FaceInstanceThumbnail_1d06b270-1b17-47fe-8f1a-c2708f6cdd61.jpg',
#                                                      'id': '1d06b270-1b17-47fe-8f1a-c2708f6cdd61',
#                                                      'instances': [{'adjustedEnd': '0:00:00.04',
#                                                                     'adjustedStart': '0:00:00',
#                                                                     'end': '0:00:00.04',
#                                                                     'start': '0:00:00'}]},
#                                                     {'fileName': 'FaceInstanceThumbnail_40898828-b03b-45d1-95fa-d57ca90c0cc7.jpg',
#                                                      'id': '40898828-b03b-45d1-95fa-d57ca90c0cc7',
#                                                      'instances': [{'adjustedEnd': '0:00:05.32',
#                                                                     'adjustedStart': '0:00:05.28',
#                                                                     'end': '0:00:05.32',
#                                                                     'start': '0:00:05.28'}]},
#                                                     {'fileName': 'FaceInstanceThumbnail_46d47124-e670-4c08-be4a-6922118e3872.jpg',
#                                                      'id': '46d47124-e670-4c08-be4a-6922118e3872',
#                                                      'instances': [{'adjustedEnd': '0:00:10.6',
#                                                                     'adjustedStart': '0:00:10.56',
#                                                                     'end': '0:00:10.6',
#                                                                     'start': '0:00:10.56'}]},
#                                                     {'fileName': 'FaceInstanceThumbnail_b1b24daf-3f6c-40ff-a285-03cdc9fc86e3.jpg',
#                                                      'id': 'b1b24daf-3f6c-40ff-a285-03cdc9fc86e3',
#                                                      'instances': [{'adjustedEnd': '0:00:15.88',
#                                                                     'adjustedStart': '0:00:15.84',
#                                                                     'end': '0:00:15.88',
#                                                                     'start': '0:00:15.84'}]},
#                                                     {'fileName': 'FaceInstanceThumbnail_aa41548a-f844-4bc1-addb-655baa2c8c87.jpg',
#                                                      'id': 'aa41548a-f844-4bc1-addb-655baa2c8c87',
#                                                      'instances': [{'adjustedEnd': '0:00:17.32',
#                                                                     'adjustedStart': '0:00:17.28',
#                                                                     'end': '0:00:17.32',
#                                                                     'start': '0:00:17.28'}]},
#                                                     {'fileName': 'FaceInstanceThumbnail_4daff412-d821-4e48-874b-de4862d38001.jpg',
#                                                      'id': '4daff412-d821-4e48-874b-de4862d38001',
#                                                      'instances': [{'adjustedEnd': '0:00:21.16',
#                                                                     'adjustedStart': '0:00:21.12',
#                                                                     'end': '0:00:21.16',
#                                                                     'start': '0:00:21.12'}]},
#                                                     {'fileName': 'FaceInstanceThumbnail_45799e86-4d84-46f1-8ea4-7698c7f39db2.jpg',
#                                                      'id': '45799e86-4d84-46f1-8ea4-7698c7f39db2',
#                                                      'instances': [{'adjustedEnd': '0:00:26.44',
#                                                                     'adjustedStart': '0:00:26.4',
#                                                                     'end': '0:00:26.44',
#                                                                     'start': '0:00:26.4'}]},
#                                                     {'fileName': 'FaceInstanceThumbnail_e19ddd83-7cde-46a5-b10d-cb933851894b.jpg',
#                                                      'id': 'e19ddd83-7cde-46a5-b10d-cb933851894b',
#                                                      'instances': [{'adjustedEnd': '0:00:31.72',
#                                                                     'adjustedStart': '0:00:31.68',
#                                                                     'end': '0:00:31.72',
#                                                                     'start': '0:00:31.68'}]},
#                                                     {'fileName': 'FaceInstanceThumbnail_1d40691b-bc50-419a-b4d7-42ca864d081a.jpg',
#                                                      'id': '1d40691b-bc50-419a-b4d7-42ca864d081a',
#                                                      'instances': [{'adjustedEnd': '0:00:37',
#                                                                     'adjustedStart': '0:00:36.96',
#                                                                     'end': '0:00:37',
#                                                                     'start': '0:00:36.96'}]},
#                                                     {'fileName': 'FaceInstanceThumbnail_18a5ab13-378a-498e-b8cf-884e9d0c9bc4.jpg',
#                                                      'id': '18a5ab13-378a-498e-b8cf-884e9d0c9bc4',
#                                                      'instances': [{'adjustedEnd': '0:00:42.28',
#                                                                     'adjustedStart': '0:00:42.24',
#                                                                     'end': '0:00:42.28',
#                                                                     'start': '0:00:42.24'}]}],
#                                      'title': None},
#                                     {'confidence': 0,
#                                      'description': None,
#                                      'highQuality': True,
#                                      'id': 1011,
#                                      'imageUrl': None,
#                                      'instances': [{'adjustedEnd': '0:00:08.2',
#                                                     'adjustedStart': '0:00:05.76',
#                                                     'end': '0:00:08.2',
#                                                     'start': '0:00:05.76',
#                                                     'thumbnailsIds': ['559025e1-a2fe-45c9-9ed9-fe92663e7e70']},
#                                                    {'adjustedEnd': '0:00:22.6',
#                                                     'adjustedStart': '0:00:20.16',
#                                                     'end': '0:00:22.6',
#                                                     'start': '0:00:20.16',
#                                                     'thumbnailsIds': ['6bbe0fce-805a-4f5d-b258-186697d15b8e']},
#                                                    {'adjustedEnd': '0:00:28.84',
#                                                     'adjustedStart': '0:00:27.36',
#                                                     'end': '0:00:28.84',
#                                                     'start': '0:00:27.36'}],
#                                      'name': 'Unknown #2',
#                                      'thumbnailId': 'c97523ac-9434-48d8-b288-7c3bfd8f63ff',
#                                      'thumbnails': [{'fileName': 'FaceInstanceThumbnail_559025e1-a2fe-45c9-9ed9-fe92663e7e70.jpg',
#                                                      'id': '559025e1-a2fe-45c9-9ed9-fe92663e7e70',
#                                                      'instances': [{'adjustedEnd': '0:00:07.24',
#                                                                     'adjustedStart': '0:00:07.2',
#                                                                     'end': '0:00:07.24',
#                                                                     'start': '0:00:07.2'}]},
#                                                     {'fileName': 'FaceInstanceThumbnail_6bbe0fce-805a-4f5d-b258-186697d15b8e.jpg',
#                                                      'id': '6bbe0fce-805a-4f5d-b258-186697d15b8e',
#                                                      'instances': [{'adjustedEnd': '0:00:21.16',
#                                                                     'adjustedStart': '0:00:21.12',
#                                                                     'end': '0:00:21.16',
#                                                                     'start': '0:00:21.12'}]}],
#                                      'title': None}],
#                           'labels': [{'id': 1,
#                                       'instances': [{'adjustedEnd': '0:00:42.04',
#                                                      'adjustedStart': '0:00:00',
#                                                      'confidence': 0.9966,
#                                                      'end': '0:00:42.04',
#                                                      'start': '0:00:00'}],
#                                       'language': 'en-US',
#                                       'name': 'clothing',
#                                       'referenceId': 'consumer goods/clothing'},
#                                      {'id': 2,
#                                       'instances': [{'adjustedEnd': '0:00:42.04',
#                                                      'adjustedStart': '0:00:00',
#                                                      'confidence': 0.9939,
#                                                      'end': '0:00:42.04',
#                                                      'start': '0:00:00'}],
#                                       'language': 'en-US',
#                                       'name': 'person',
#                                       'referenceId': 'person'},
#                                      {'id': 3,
#                                       'instances': [{'adjustedEnd': '0:00:03.04',
#                                                      'adjustedStart': '0:00:00',
#                                                      'confidence': 0.9883,
#                                                      'end': '0:00:03.04',
#                                                      'start': '0:00:00'},
#                                                     {'adjustedEnd': '0:00:15.04',
#                                                      'adjustedStart': '0:00:05',
#                                                      'confidence': 0.9802,
#                                                      'end': '0:00:15.04',
#                                                      'start': '0:00:05'},
#                                                     {'adjustedEnd': '0:00:42.04',
#                                                      'adjustedStart': '0:00:18',
#                                                      'confidence': 0.9881,
#                                                      'end': '0:00:42.04',
#                                                      'start': '0:00:18'}],
#                                       'language': 'en-US',
#                                       'name': 'human face'},
#                                      {'id': 4,
#                                       'instances': [{'adjustedEnd': '0:00:03.04',
#                                                      'adjustedStart': '0:00:00',
#                                                      'confidence': 0.9593,
#                                                      'end': '0:00:03.04',
#                                                      'start': '0:00:00'},
#                                                     {'adjustedEnd': '0:00:05.04',
#                                                      'adjustedStart': '0:00:05',
#                                                      'confidence': 0.9539,
#                                                      'end': '0:00:05.04',
#                                                      'start': '0:00:05'},
#                                                     {'adjustedEnd': '0:00:14.04',
#                                                      'adjustedStart': '0:00:09',
#                                                      'confidence': 0.972,
#                                                      'end': '0:00:14.04',
#                                                      'start': '0:00:09'},
#                                                     {'adjustedEnd': '0:00:19.04',
#                                                      'adjustedStart': '0:00:16',
#                                                      'confidence': 0.955,
#                                                      'end': '0:00:19.04',
#                                                      'start': '0:00:16'},
#                                                     {'adjustedEnd': '0:00:42.04',
#                                                      'adjustedStart': '0:00:21',
#                                                      'confidence': 0.9729,
#                                                      'end': '0:00:42.04',
#                                                      'start': '0:00:21'}],
#                                       'language': 'en-US',
#                                       'name': 'indoor'},
#                                      {'id': 5,
#                                       'instances': [{'adjustedEnd': '0:00:03.04',
#                                                      'adjustedStart': '0:00:02',
#                                                      'confidence': 0.9524,
#                                                      'end': '0:00:03.04',
#                                                      'start': '0:00:02'}],
#                                       'language': 'en-US',
#                                       'name': 'coat',
#                                       'referenceId': 'covering/clothing/coat'},
#                                      {'id': 6,
#                                       'instances': [{'adjustedEnd': '0:00:09.04',
#                                                      'adjustedStart': '0:00:09',
#                                                      'confidence': 0.9651,
#                                                      'end': '0:00:09.04',
#                                                      'start': '0:00:09'},
#                                                     {'adjustedEnd': '0:00:19.04',
#                                                      'adjustedStart': '0:00:19',
#                                                      'confidence': 0.9614,
#                                                      'end': '0:00:19.04',
#                                                      'start': '0:00:19'},
#                                                     {'adjustedEnd': '0:00:23.04',
#                                                      'adjustedStart': '0:00:22',
#                                                      'confidence': 0.955,
#                                                      'end': '0:00:23.04',
#                                                      'start': '0:00:22'},
#                                                     {'adjustedEnd': '0:00:26.04',
#                                                      'adjustedStart': '0:00:25',
#                                                      'confidence': 0.9555,
#                                                      'end': '0:00:26.04',
#                                                      'start': '0:00:25'},
#                                                     {'adjustedEnd': '0:00:28.04',
#                                                      'adjustedStart': '0:00:28',
#                                                      'confidence': 0.9616,
#                                                      'end': '0:00:28.04',
#                                                      'start': '0:00:28'},
#                                                     {'adjustedEnd': '0:00:36.04',
#                                                      'adjustedStart': '0:00:31',
#                                                      'confidence': 0.957,
#                                                      'end': '0:00:36.04',
#                                                      'start': '0:00:31'},
#                                                     {'adjustedEnd': '0:00:40.04',
#                                                      'adjustedStart': '0:00:38',
#                                                      'confidence': 0.9579,
#                                                      'end': '0:00:40.04',
#                                                      'start': '0:00:38'}],
#                                       'language': 'en-US',
#                                       'name': 'wall',
#                                       'referenceId': 'structure/wall'},
#                                      {'id': 7,
#                                       'instances': [{'adjustedEnd': '0:00:12.04',
#                                                      'adjustedStart': '0:00:11',
#                                                      'confidence': 0.9713,
#                                                      'end': '0:00:12.04',
#                                                      'start': '0:00:11'},
#                                                     {'adjustedEnd': '0:00:14.04',
#                                                      'adjustedStart': '0:00:14',
#                                                      'confidence': 0.9536,
#                                                      'end': '0:00:14.04',
#                                                      'start': '0:00:14'},
#                                                     {'adjustedEnd': '0:00:18.04',
#                                                      'adjustedStart': '0:00:17',
#                                                      'confidence': 0.9632,
#                                                      'end': '0:00:18.04',
#                                                      'start': '0:00:17'},
#                                                     {'adjustedEnd': '0:00:24.04',
#                                                      'adjustedStart': '0:00:22',
#                                                      'confidence': 0.9641,
#                                                      'end': '0:00:24.04',
#                                                      'start': '0:00:22'}],
#                                       'language': 'en-US',
#                                       'name': 'drink',
#                                       'referenceId': 'drink'},
#                                      {'id': 8,
#                                       'instances': [{'adjustedEnd': '0:00:11.04',
#                                                      'adjustedStart': '0:00:11',
#                                                      'confidence': 0.9583,
#                                                      'end': '0:00:11.04',
#                                                      'start': '0:00:11'},
#                                                     {'adjustedEnd': '0:00:20.04',
#                                                      'adjustedStart': '0:00:20',
#                                                      'confidence': 0.9566,
#                                                      'end': '0:00:20.04',
#                                                      'start': '0:00:20'},
#                                                     {'adjustedEnd': '0:00:29.04',
#                                                      'adjustedStart': '0:00:24',
#                                                      'confidence': 0.9552,
#                                                      'end': '0:00:29.04',
#                                                      'start': '0:00:24'},
#                                                     {'adjustedEnd': '0:00:34.04',
#                                                      'adjustedStart': '0:00:32',
#                                                      'confidence': 0.9538,
#                                                      'end': '0:00:34.04',
#                                                      'start': '0:00:32'}],
#                                       'language': 'en-US',
#                                       'name': 'man',
#                                       'referenceId': 'person/man'},
#                                      {'id': 9,
#                                       'instances': [{'adjustedEnd': '0:00:18.04',
#                                                      'adjustedStart': '0:00:17',
#                                                      'confidence': 0.9633,
#                                                      'end': '0:00:18.04',
#                                                      'start': '0:00:17'},
#                                                     {'adjustedEnd': '0:00:23.04',
#                                                      'adjustedStart': '0:00:23',
#                                                      'confidence': 0.9534,
#                                                      'end': '0:00:23.04',
#                                                      'start': '0:00:23'}],
#                                       'language': 'en-US',
#                                       'name': 'wine glass'},
#                                      {'id': 10,
#                                       'instances': [{'adjustedEnd': '0:00:32.04',
#                                                      'adjustedStart': '0:00:32',
#                                                      'confidence': 0.9591,
#                                                      'end': '0:00:32.04',
#                                                      'start': '0:00:32'}],
#                                       'language': 'en-US',
#                                       'name': 'suit',
#                                       'referenceId': 'consumer '
#                                                      'goods/clothing/suit'}],
#                           'language': 'en-US',
#                           'languages': ['en-US'],
#                           'ocr': [{'angle': -1,
#                                    'confidence': 0.937,
#                                    'height': 49,
#                                    'id': 1,
#                                    'instances': [{'adjustedEnd': '0:00:19.04',
#                                                   'adjustedStart': '0:00:19',
#                                                   'end': '0:00:19.04',
#                                                   'start': '0:00:19'}],
#                                    'language': 'fr-FR',
#                                    'left': 576,
#                                    'text': 'BAT',
#                                    'top': 1595,
#                                    'width': 137},
#                                   {'angle': 180,
#                                    'confidence': 0.968,
#                                    'height': 24,
#                                    'id': 2,
#                                    'instances': [{'adjustedEnd': '0:00:33.04',
#                                                   'adjustedStart': '0:00:31',
#                                                   'end': '0:00:33.04',
#                                                   'start': '0:00:31'}],
#                                    'language': 'en-US',
#                                    'left': 145,
#                                    'text': 'Than',
#                                    'top': 3436,
#                                    'width': 123},
#                                   {'angle': 0,
#                                    'confidence': 0.963,
#                                    'height': 45,
#                                    'id': 3,
#                                    'instances': [{'adjustedEnd': '0:00:34.04',
#                                                   'adjustedStart': '0:00:34',
#                                                   'end': '0:00:34.04',
#                                                   'start': '0:00:34'}],
#                                    'language': 'fr-FR',
#                                    'left': 8,
#                                    'text': 'LES',
#                                    'top': 3534,
#                                    'width': 117},
#                                   {'angle': -1,
#                                    'confidence': 0.996,
#                                    'height': 94,
#                                    'id': 4,
#                                    'instances': [{'adjustedEnd': '0:00:40.04',
#                                                   'adjustedStart': '0:00:35',
#                                                   'end': '0:00:40.04',
#                                                   'start': '0:00:35'}],
#                                    'language': 'en-US',
#                                    'left': 10,
#                                    'text': 'OFF',
#                                    'top': 3302,
#                                    'width': 246},
#                                   {'angle': -178,
#                                    'confidence': 0.97,
#                                    'height': 28,
#                                    'id': 5,
#                                    'instances': [{'adjustedEnd': '0:00:35.04',
#                                                   'adjustedStart': '0:00:35',
#                                                   'end': '0:00:35.04',
#                                                   'start': '0:00:35'}],
#                                    'language': 'en-US',
#                                    'left': 399,
#                                    'text': 'Tha',
#                                    'top': 3445,
#                                    'width': 99},
#                                   {'angle': -3,
#                                    'confidence': 0.998,
#                                    'height': 59,
#                                    'id': 6,
#                                    'instances': [{'adjustedEnd': '0:00:36.04',
#                                                   'adjustedStart': '0:00:35',
#                                                   'end': '0:00:36.04',
#                                                   'start': '0:00:35'}],
#                                    'language': 'en-US',
#                                    'left': 11,
#                                    'text': 'STYLES',
#                                    'top': 3513,
#                                    'width': 262},
#                                   {'angle': -2,
#                                    'confidence': 0.998,
#                                    'height': 85,
#                                    'id': 7,
#                                    'instances': [{'adjustedEnd': '0:00:37.04',
#                                                   'adjustedStart': '0:00:37',
#                                                   'end': '0:00:37.04',
#                                                   'start': '0:00:37'},
#                                                  {'adjustedEnd': '0:00:39.04',
#                                                   'adjustedStart': '0:00:39',
#                                                   'end': '0:00:39.04',
#                                                   'start': '0:00:39'}],
#                                    'language': 'en-US',
#                                    'left': 11,
#                                    'text': 'RA',
#                                    'top': 3183,
#                                    'width': 174},
#                                   {'angle': -3,
#                                    'confidence': 0.997,
#                                    'height': 59,
#                                    'id': 8,
#                                    'instances': [{'adjustedEnd': '0:00:39.04',
#                                                   'adjustedStart': '0:00:37',
#                                                   'end': '0:00:39.04',
#                                                   'start': '0:00:37'}],
#                                    'language': 'es-ES',
#                                    'left': 6,
#                                    'text': 'ES STYLES',
#                                    'top': 3516,
#                                    'width': 358},
#                                   {'angle': 0,
#                                    'confidence': 0.995,
#                                    'height': 61,
#                                    'id': 9,
#                                    'instances': [{'adjustedEnd': '0:00:40.04',
#                                                   'adjustedStart': '0:00:40',
#                                                   'end': '0:00:40.04',
#                                                   'start': '0:00:40'},
#                                                  {'adjustedEnd': '0:00:42.04',
#                                                   'adjustedStart': '0:00:42',
#                                                   'end': '0:00:42.04',
#                                                   'start': '0:00:42'}],
#                                    'language': 'fr-FR',
#                                    'left': 10,
#                                    'text': 'YLES',
#                                    'top': 3489,
#                                    'width': 191},
#                                   {'angle': -1,
#                                    'confidence': 0.983,
#                                    'height': 48,
#                                    'id': 10,
#                                    'instances': [{'adjustedEnd': '0:00:41.04',
#                                                   'adjustedStart': '0:00:41',
#                                                   'end': '0:00:41.04',
#                                                   'start': '0:00:41'}],
#                                    'language': 'es-ES',
#                                    'left': 13,
#                                    'text': 'ES',
#                                    'top': 3485,
#                                    'width': 101}],
#                           'scenes': [{'id': 1,
#                                       'instances': [{'adjustedEnd': '0:00:42.4799999',
#                                                      'adjustedStart': '0:00:00',
#                                                      'end': '0:00:42.4799999',
#                                                      'start': '0:00:00'}]}],
#                           'shots': [{'id': 1,
#                                      'instances': [{'adjustedEnd': '0:00:42.4799999',
#                                                     'adjustedStart': '0:00:00',
#                                                     'end': '0:00:42.4799999',
#                                                     'start': '0:00:00'}],
#                                      'keyFrames': [{'id': 1,
#                                                     'instances': [{'adjustedEnd': '0:00:04.4',
#                                                                    'adjustedStart': '0:00:04.36',
#                                                                    'end': '0:00:04.4',
#                                                                    'start': '0:00:04.36',
#                                                                    'thumbnailId': '4ee2ad59-1fb1-4751-8a69-a62da3c9009d'}]},
#                                                    {'id': 2,
#                                                     'instances': [{'adjustedEnd': '0:00:28.96',
#                                                                    'adjustedStart': '0:00:28.92',
#                                                                    'end': '0:00:28.96',
#                                                                    'start': '0:00:28.92',
#                                                                    'thumbnailId': '07048302-d642-4416-a716-4e937c7a2a6e'}]}],
#                                      'tags': ['Medium', 'LeftFace']}],
#                           'sourceLanguage': 'en-US',
#                           'sourceLanguages': ['en-US'],
#                           'statistics': {'correspondenceCount': 0,
#                                          'speakerLongestMonolog': {},
#                                          'speakerNumberOfFragments': {},
#                                          'speakerTalkToListenRatio': {},
#                                          'speakerWordCount': {}},
#                           'textualContentModeration': {'bannedWordsCount': 0,
#                                                        'bannedWordsRatio': 0,
#                                                        'id': 0,
#                                                        'instances': []},
#                           'version': '1.0.0.0'},
#              'isAdult': False,
#              'isSearchable': True,
#              'language': 'en-US',
#              'languageAutoDetectMode': 'None',
#              'languages': ['en-US'],
#              'linguisticModelId': '00000000-0000-0000-0000-000000000000',
#              'logoGroupId': None,
#              'metadata': None,
#              'moderationState': 'OK',
#              'personModelId': '00000000-0000-0000-0000-000000000000',
#              'privacyMode': 'Private',
#              'processingProgress': '100%',
#              'publishedProxyUrl': None,
#              'publishedUrl': 'https://api.videoindexer.ai/internals/eastus/Accounts/84bdc98e-e016-4228-b796-c43bb634905a/Videos/wufte6jyyg/streaming-manifest/manifest.m3u8',
#              'reviewState': 'None',
#              'sourceLanguage': 'en-US',
#              'sourceLanguages': ['en-US'],
#              'state': 'Processed',
#              'streamingPreset': 'Default',
#              'thumbnailId': '5273bf0c-2c39-4ef0-b9fb-5977f3ca4bac',
#              'viewToken': 'eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9.....dy8bLbuDeLfLKMdvOWwZ_GzdXA4IFfCCxMADDvcWdTwRHSPWoXpN4I5-V7yPbVky_UFIJ9UdOiZHQ0okP2Ih_jPswpJZ20NLiIgttNTi_qnGm3Y9s3lPs2dLZLUhDugJCR5YMJ-neImynUZ2G_ltIRlAxCCEm2KKoIHUovsxXSRTEDK3k8oEEz5b_RA2yxzowomco7tI2biEgVsUskMBd3nl_Z87in0z9c46kq_ndDceo0yEkKrRyPC9UvL5jD_vlVp-ov2MOdVoQ3qmUOM_11lrwNVco3JuHHMNFRgwZkras2KDuhyWT45XjXiVeguwW5RejKT2a2rnkbn10IaG_Q',
#              'width': 2160}],
#  'videosRanges': [{'range': {'end': '0:00:42.4799999', 'start': '0:00:00'},
#                    'videoId': 'wufte6jyyg'}]}

# %% [markdown]
# ### Widgets API
# <hr>

# %%
client.get_insights_widgets_url_async(file_video_id, widget_type='Keywords')
client.get_player_widget_url_async(file_video_id)
# Out:
# Getting the insights widget URL for video wufte6jyyg
# Got the insights widget URL: https://www.videoindexer.ai/embed/insights/84bdc98e-e016-4228-b796-c43bb634905a/wufte6jyyg/?location=eastus&widgets=Keywords&accessToken=eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9.....Arp2i1q6rOaEQhumQFApN87-GFeX1FYLrJCcGpXms3I5ExT7ezrH7fG8hxzKwk7X-Ek1ihaUExLCL2mLu6IvoCZcKZs_wYTLBcmbSAA6YPyLqgngTa6o18T5vALF211Eu3J8SNHP0apcpRLGm9v7HFOJw99wsWzKrIUl_uRA5IP3OekuV4l2SjxlAmSpEU_Vjo2qQNx5VjqxiADwJeZ8K12AJGohUG8Fe4OHN9KyJ5npsHSIQ7EgHoBVkPW-qviNZqMC-4PvCEyOVTRrEURrfCYZD7M8Qb60mgFTrm78DNDhZs1AjfUDVF5y-voISEeRHsC5jEj5v4pvAYYDBvkvPg
# Getting the player widget URL for video wufte6jyyg
# Got the player widget URL: https://www.videoindexer.ai/embed/player/84bdc98e-e016-4228-b796-c43bb634905a/wufte6jyyg/?location=eastus&accessToken=eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9.....HuxyXHgz9Ot1nLNkOpgVB1iG2Iv2gkUDeYF2AxCaVel2uFjmD9n2s3J5vD0XK4KjTAWQS-5Qh9d3iBjFgkQI_Gs1NS4Sg4f-Uycl1zRUdP-Mziq-UcGcodUpsVOkN5Dk1zcyiJYWeaL5FtgOYLivgj-kZOKH1iKLPpkncCakiSeQJhh7LjSHQpnRJk-bzP9TZaYdeykxUDjTj2tK-HvE3xtu058TuZnXN0g2rZhOu5R7zPP2mHlP5tUj3o1U9EAFYdtN-HHHt49rm6T3L8cDuzOv7vwIrwNnhNAqhSr0pMEogLgJH_3zg9BRKQUG69RMdhwlV2SbgjV_TN6Z9qXB1Q

# %% [markdown]
# ### Prompt Content API
# <hr>

# %%
prompt_content = client.get_prompt_content(file_video_id)
pprint(prompt_content)
# Out:
# Prompt content generation for video_id='0f2eb45f72' started...
# Prompt content is not ready yet. Waiting 5 seconds before checking again...
# Prompt content is not ready yet. Waiting 5 seconds before checking again...
# {'name': 'Sales',
#  'partition': None,
#  'sections': [{'content': '[Video title] Sales\n'
#                           '[Detected objects] dining table, necktie, wine '
#                           'glass\n'
#                           '[Visual labels] clothing, person, human face, '
#                           'indoor, coat, wall, drink, man, wine glass, suit\n'
#                           '[OCR] BAT, Than, LES, OFF, Tha, STYLES, RA, ES '
#                           'STYLES, YLES, ES',
#                'end': '0:00:42.48',
#                'id': 0,
#                'start': '0:00:00'}]}
